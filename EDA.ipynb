# %%
# importing all the required module
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from statsmodels import robust as ro

# %%
#impoting data set
data_set=pd.read_csv("haberman.csv")
data_set
# Out:
#      age  year  nodes  status
# 0     30    64      1       1
# 1     30    62      3       1
# 2     30    65      0       1
# 3     31    59      2       1
# 4     31    65      4       1
# ..   ...   ...    ...     ...
# 301   75    62      1       1
# 302   76    67      0       1
# 303   77    65      3       1
# 304   78    65      1       2
# 305   83    58      2       2
#
# [306 rows x 4 columns]

# %%
#acknowledging the data set
data_set.shape
# Out:
# (306, 4)

# %%
#grouping data set
data_set["status"].value_counts()
# Out:
# 1    225
# 2     81
# Name: status, dtype: int64

# %%
#looking at the columns
data_set.status
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 301    1
# 302    1
# 303    1
# 304    2
# 305    2
# Name: status, Length: 306, dtype: int64

# %%
data_set.year
# Out:
# 0      64
# 1      62
# 2      65
# 3      59
# 4      65
#        ..
# 301    62
# 302    67
# 303    65
# 304    65
# 305    58
# Name: year, Length: 306, dtype: int64

# %%
data_set.nodes
# Out:
# 0      1
# 1      3
# 2      0
# 3      2
# 4      4
#       ..
# 301    1
# 302    0
# 303    3
# 304    1
# 305    2
# Name: nodes, Length: 306, dtype: int64

# %%
# 2-d scatter plot
data_set.plot(kind="scatter",x="age",y="nodes")

# %%
# 2-D SCATTER PLOT WITH DIFFERENT COLOR.
sns.set_style("whitegrid")
sns.FacetGrid(data_set,hue="status",height=6) \
    .map(plt.scatter,"age","nodes") \
    .add_legend();
plt.show()

# %%
sns.set_style("whitegrid")
sns.FacetGrid(data_set,hue="status",height=6) \
    .map(pyp.scatter,"year","nodes") \
    .add_legend();
pyp.show()

# %%
sns.set_style("whitegrid")
sns.FacetGrid(data_set,hue="status",height=6) \
    .map(pyp.scatter,"age","year") \
    .add_legend();
pyp.show()

# %%
sns.set_style("whitegrid")
sns.FacetGrid(data_set,hue="status",height=4) \
    .map(pyp.scatter,"nodes","age") \
    .add_legend();
pyp.show()

# %%
sns.set_style("whitegrid")
sns.FacetGrid(data_set,hue="status",height=4) \
    .map(pyp.scatter,"nodes","year") \
    .add_legend();
pyp.show()

# %%
sns.set_style("whitegrid")
sns.FacetGrid(data_set,hue="status",height=4) \
    .map(pyp.scatter,"year","age") \
    .add_legend();
pyp.show()

# %%
CLASSIFICATION THE GIVEN DATA ON THE BASIS OF STATUS OF PATIENT

# %% [markdown]
# univariate data analysic

# %% [markdown]
# 1.scatter plot

# %% [markdown]
# 2.histogram

# %% [markdown]
# 3.pdf,cdf

# %% [markdown]
# 4.box plot

# %% [markdown]
# 5.violin plot

# %%
# ADDING VARIABLE TO THE COLUMN 
data_positive=data_set.loc[data_set["status"]==1]
data_positive
# Out:
#      age  year  nodes  status
# 0     30    64      1       1
# 1     30    62      3       1
# 2     30    65      0       1
# 3     31    59      2       1
# 4     31    65      4       1
# ..   ...   ...    ...     ...
# 298   73    68      0       1
# 300   74    63      0       1
# 301   75    62      1       1
# 302   76    67      0       1
# 303   77    65      3       1
#
# [225 rows x 4 columns]

# %%
data_negative=data_set.loc[data_set.status==2]
data_negative
# Out:
#      age  year  nodes  status
# 7     34    59      0       2
# 8     34    66      9       2
# 24    38    69     21       2
# 34    39    66      0       2
# 43    41    60     23       2
# ..   ...   ...    ...     ...
# 286   70    58      4       2
# 293   72    63      0       2
# 299   74    65      3       2
# 304   78    65      1       2
# 305   83    58      2       2
#
# [81 rows x 4 columns]

# %%
#PLOTTING 1-D SCATTER PLOT
plt.plot(data_positive["nodes"],np.zeros_like(data_positive["nodes"]),'go')
plt.plot(data_negative["nodes"],np.zeros_like(data_negative["nodes"]),'r^')
plt.show()
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# UNIVARIATE DATA PLOT

# %%
#PLOTTING 1-D DISTRIBUTION PLOT
sns.set_style("whitegrid")
sns.FacetGrid(data_set,hue="status",height=5) \
    .map(sns.distplot,"age") \
    .add_legend();
plt.show();

# %%
sns.set_style("whitegrid")
sns.FacetGrid(data_set,hue="status",height=5) \
    .map(sns.distplot,"nodes") \
    .add_legend();
plt.show();

# %%
sns.set_style("whitegrid")
sns.FacetGrid(data_set,hue="status",height=5) \
    .map(sns.distplot,"year") \
    .add_legend();
plt.show();

# %% [markdown]
# PDF ,CDF

# %%
#ANALYSING DISTRIBUTIVE PLOT ON THE BASIS OF PDF(SMMOTHNING),CDF
count,bin_edges=np.histogram(data_positive["nodes"],10,density=True)
print("count",count)
print(bin_edges)
pdf=count/(sum(count))
print("pdf:",pdf)
data_positive.nodes.min()
cdf=np.cumsum(pdf)
print(cdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
count,bin_edges=np.histogram(data_negative["nodes"],10,density=True)
print("count",count)
print(bin_edges)
pdf=count/(sum(count))
print("pdf:",pdf)
data_positive.nodes.min()
cdf=np.cumsum(pdf)
print(cdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show()
# Out:
# count [0.18164251 0.0173913  0.00483092 0.0057971  0.00386473 0.00096618
#  0.00193237 0.         0.         0.00096618]
# [ 0.   4.6  9.2 13.8 18.4 23.  27.6 32.2 36.8 41.4 46. ]
# pdf: [0.83555556 0.08       0.02222222 0.02666667 0.01777778 0.00444444
#  0.00888889 0.         0.         0.00444444]
# [0.83555556 0.91555556 0.93777778 0.96444444 0.98222222 0.98666667
#  0.99555556 0.99555556 0.99555556 1.        ]
# count [0.10921178 0.02849003 0.02611586 0.00949668 0.01424501 0.
#  0.00237417 0.         0.         0.00237417]
# [ 0.   5.2 10.4 15.6 20.8 26.  31.2 36.4 41.6 46.8 52. ]
# pdf: [0.56790123 0.14814815 0.13580247 0.04938272 0.07407407 0.
#  0.01234568 0.         0.         0.01234568]
# [0.56790123 0.71604938 0.85185185 0.90123457 0.97530864 0.97530864
#  0.98765432 0.98765432 0.98765432 1.        ]

# %%
data_negative.age.describe()
# Out:
# count    81.000000
# mean     53.679012
# std      10.167137
# min      34.000000
# 25%      46.000000
# 50%      53.000000
# 75%      61.000000
# max      83.000000
# Name: age, dtype: float64

# %% [markdown]
# 1-D DATA:BOX PLOT

# %%
#ANALYSING DATA AND PREPARING THE MODEL AND MINIMISING THE ERROE 
sns.boxplot(x='status',y='nodes',data=data_set)
plt.show()

# %%
#VIOLIN PLOT IS THE COMBINATION OF BOX PLOT AND PDF
sns.violinplot(x='status',y='nodes',data=data_set,height=7)

# %%
#2D PROBABILITY DISTRIBUTION FUNCTION
sns.jointplot(x='nodes',y='year',data=data_positive,kind='kde')

# %%
sns.jointplot(x='nodes',y='year',data=data_negative,kind='kde')

# %%
#2-D PAIR PLOT
sns.set_style('whitegrid')
sns.pairplot(data_set,hue='status',height=4)
# Out:
# /home/rahul_mahaseth/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/rahul_mahaseth/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
data_positive.age.describe()
# Out:
# count    225.000000
# mean      52.017778
# std       11.012154
# min       30.000000
# 25%       43.000000
# 50%       52.000000
# 75%       60.000000
# max       77.000000
# Name: age, dtype: float64
